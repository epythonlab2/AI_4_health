# %% [markdown]
# <a href="https://colab.research.google.com/github/epythonlab2/AI_4_health/blob/main/module_3_1_health_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <header style="font-family: 'Inter', sans-serif; background: #ffffff; padding: 16px; border-radius: 8px; border: 1px solid #e1e4e8; display: flex; align-items: center; gap: 12px; box-shadow: 0 2px 8px rgba(0,0,0,0.05); margin-bottom: 10px;">
#     <div style="width: 4px; height: 35px; background: linear-gradient(to bottom, #4e73df, #1cc88a); border-radius: 2px;"></div>
#     <h1 style="color: #1a1a1a; margin: 0; font-size: 20px; font-weight: 700; border: none;">Module 3: Applications in Healthcare & Finance</h1>
# </header>
#
# <div style="font-family: 'Inter', sans-serif; max-width: 900px; margin: 15px 0; padding: 20px; border-radius: 10px; background: #f1f4ff; border: 1px solid #dbe3ff; display: flex; align-items: center; justify-content: space-between; gap: 15px;">
#     <div style="flex: 1;">
#         <h2 style="margin: 0; color: #2e59d9; font-size: 18px; font-weight: 700; border: none;">Chapter 1: Healthcare Analytics</h2>
#         <span style="display: inline-block; margin-top: 8px; background: #ffffff; padding: 4px 12px; border-radius: 6px; color: #4e73df; font-weight: 800; font-size: 11px; border: 1px solid #dbe3ff; text-transform: uppercase;">12 Hours</span>
#     </div>
#
#    <a href="https://linkedin.com/in/dejenet" target="_blank" style="background-color: #0077b5; color: white; padding: 10px 20px; border-radius: 8px; text-decoration: none; font-size: 14px; font-weight: 700; white-space: nowrap;">
#         Connect on LinkedIn
#     </a>
# </div>

# %% [markdown]
# ###**1. Healthcare Analytics: EHR Data & Privacy**

# %% [markdown]
# ####**1.1 What is an EHR?**
#
# An Electronic Health Record (EHR) is a digital version of a patient’s medical history maintained by healthcare providers over time.
#
# It includes:
# - Demographics, Diagnoses, Lab results
#
# - Medications, Clinical notes, Imaging reports
#
# - Vital signs, Procedures
#
# **Examples of EHR Vendors**
#
# Some of the major EHR systems include:
#
# - [Epic Systems](https://www.epic.com/) is privately held American healthcare software company best known for its electronic health record (EHR) platform used by many of the largest hospitals and health systems in the world.
#
# - [Cerner](https://www.oracle.com/health/) is a healthcare information technology company best known as a major provider of electronic health record (EHR) and clinical software to hospitals and health systems.
#
# - Allscripts
#
# - Meditech
#
# These platforms manage millions of patient records and are widely used by hospitals worldwide.
#
# **EHRs** are built for clinical documentation and billing, not for machine learning. That’s why analytics teams must transform and clean the data carefully.

# %% [markdown]
# ####**1.2 EHR Data Types – Structured vs Unstructured**

# %% [markdown]
# Healthcare data is messy. It is multimodal and longitudinal. It comes in two main forms
#
# **1. Structured Data:** Organized and machine-readable.
#
# - Demographics (age, sex, address)
#
# - Vital signs (blood pressure, heart rate)
#
# - Lab results (glucose, creatinine)
#
# - Diagnosis codes (ICD codes)
#
# - Procedure codes (CPT codes)
#
# - Medications
#
# This data is stored in tables and columns and is easier to use for analytics.

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#         }
#         table {
#             border-collapse: collapse;
#             margin-bottom: 40px;
#             width: 90%;
#         }
#         th, td {
#             border: 1px solid #333;
#             padding: 8px;
#             text-align: left;
#         }
#         th {
#             background-color: #f2f2f2;
#         }
#         h2 {
#             margin-top: 50px;
#         }
#         .note {
#             font-size: 14px;
#             color: #555;
#         }
#     </style>
# </head>
# <body>
#
# <h1>EHR Relational Database Demo</h1>
#
#
# <!-- 1. Patient Table -->
# <h2>1. Patient Table</h2>
# <table>
#     <tr>
#         <th>patient_id (PK)</th>
#         <th>date_of_birth</th>
#         <th>gender</th>
#         <th>address</th>
#     </tr>
#     <tr>
#         <td>P001</td>
#         <td>1985-03-12</td>
#         <td>Female</td>
#         <td>Addis Ababa</td>
#     </tr>
#     <tr>
#         <td>P002</td>
#         <td>1990-07-25</td>
#         <td>Male</td>
#         <td>Bahir Dar</td>
#     </tr>
# </table>
#
# <!-- 2. Admissions Table -->
# <h2>2. Admissions Table</h2>
# <p class="note">patient_id is a Foreign Key → links to Patient Table</p>
# <table>
#     <tr>
#         <th>admission_id (PK)</th>
#         <th>patient_id (FK)</th>
#         <th>admission_date</th>
#         <th>discharge_date</th>
#     </tr>
#     <tr>
#         <td>A1001</td>
#         <td>P001</td>
#         <td>2026-01-10</td>
#         <td>2026-01-15</td>
#     </tr>
#     <tr>
#         <td>A1002</td>
#         <td>P002</td>
#         <td>2026-02-01</td>
#         <td>2026-02-05</td>
#     </tr>
# </table>
#
# <!-- 3. Diagnosis Table -->
# <h2>3. Diagnosis Table</h2>
# <p class="note">admission_id links to Admissions Table</p>
# <table>
#     <tr>
#         <th>diagnosis_id (PK)</th>
#         <th>admission_id (FK)</th>
#         <th>ICD_code</th>
#         <th>diagnosis_description</th>
#     </tr>
#     <tr>
#         <td>D9001</td>
#         <td>A1001</td>
#         <td>I10</td>
#         <td>Essential Hypertension</td>
#     </tr>
#     <tr>
#         <td>D9002</td>
#         <td>A1002</td>
#         <td>E11</td>
#         <td>Type 2 Diabetes Mellitus</td>
#     </tr>
# </table>
#
# <!-- 4. Labs Table -->
# <h2>4. Labs Table</h2>
# <p class="note">patient_id links to Patient Table</p>
# <table>
#     <tr>
#         <th>lab_id (PK)</th>
#         <th>patient_id (FK)</th>
#         <th>lab_test_name</th>
#         <th>result_value</th>
#         <th>test_date</th>
#     </tr>
#     <tr>
#         <td>L5001</td>
#         <td>P001</td>
#         <td>Hemoglobin</td>
#         <td>12.5 g/dL</td>
#         <td>2026-01-11</td>
#     </tr>
#     <tr>
#         <td>L5002</td>
#         <td>P002</td>
#         <td>Fasting Glucose</td>
#         <td>140 mg/dL</td>
#         <td>2026-02-02</td>
#     </tr>
# </table>
#
# <!-- 5. Medications Table -->
# <h2>5. Medications Table</h2>
# <p class="note">patient_id links to Patient Table</p>
# <table>
#     <tr>
#         <th>medication_id (PK)</th>
#         <th>patient_id (FK)</th>
#         <th>drug_name</th>
#         <th>dose</th>
#         <th>start_date</th>
#         <th>end_date</th>
#     </tr>
#     <tr>
#         <td>M3001</td>
#         <td>P001</td>
#         <td>Lisinopril</td>
#         <td>10 mg daily</td>
#         <td>2026-01-12</td>
#         <td>2026-06-12</td>
#     </tr>
#     <tr>
#         <td>M3002</td>
#         <td>P002</td>
#         <td>Metformin</td>
#         <td>500 mg twice daily</td>
#         <td>2026-02-02</td>
#         <td>2026-08-02</td>
#     </tr>
# </table>
#
# </body>
# </html>

# %% [markdown]
# **2. Unstructured Data**: Free-text or complex data.
#
# **Examples:**
#
# - Doctor’s notes
#
# - Discharge summaries
#
# - Radiology reports
#
# - Pathology reports
#
# Unstructured data often contains the richest clinical information but requires:
#
# - Natural Language Processing (NLP)
#
# - Text preprocessing
#
# - Clinical concept extraction
#
# In real-world healthcare AI, combining structured and unstructured data gives stronger models.

# %% [markdown]
# **Time-Series Nature of Healthcare Data**:- Healthcare data is not static. It evolves over time.
#
# TEHR is temporal:
#
# - A patient may have multiple admissions
#
# - Lab values change over time
#
# - Medication changes
# - Repeated lab tests
# - Disease progression
#
# So we often deal with:
#
# - Sequential modeling
#
# - Survival analysis
#
# - Event prediction
#
# For example:
#
# - Day 1 → Admission
# - Day 2 → Lab test
# - Day 3 → Medication adjustment
# - Day 5 → Discharge
#
# In predictive modeling (e.g., readmission prediction), time matters. You must decide:
#
# - What is the prediction point?
#
# - What historical window do you use?
#
# - Are you leaking future information?
#
# Temporal leakage is a common and dangerous mistake in healthcare ML.

# %% [markdown]
# ####**1.3 EHR Standards – HL7 & FHIR**:
# Healthcare systems need to communicate with each other. That’s where interoperability standards come in.
#
# **HL7**: [Health Level Seven International](https://www.hl7.org/) develops the HL7 standards.
#
# - defines how clinical data is exchanged between systems.
#
# **FHIR**: [HL7 FHIR](https://www.hl7.org/fhir/overview.html) (Fast Healthcare Interoperability Resources) is a modern standard built on web technologies.
#
# **FHIR:**
#
# - Uses REST APIs
#
# - Supports JSON and XML
#
# - Makes integration easier for modern applications
#
# For healthcare AI engineers, understanding FHIR is critical when building:
#
# - Clinical dashboards
#
# - Decision support systems
#
# - Data pipelines from hospital systems

# %% [markdown]
# ####**1.4 Privacy & Security – HIPAA, GDPR**
#
# Healthcare data is among the most sensitive types of data.
#
# **HIPAA**
#
# Health Insurance Portability and Accountability Act (HIPAA) regulates patient data protection in the United States.
#
# It defines:
#
# - Protected Health Information (PHI)
#
# - Data access rules
#
# - Security requirements
#
# - Breach reporting obligations
#
# **GDPR**
#
# General Data Protection Regulation (GDPR) governs data privacy in the European Union.
#
# It emphasizes:
#
# - Consent
#
# - Right to access data
#
# - Right to be forgotten
#
# - Data minimization
#
# - De-identification
#
# Before using EHR data for research or ML:
#
# - Remove names
#
# - Remove addresses
#
# - Remove phone numbers
#
# - Remove national identifiers
#
# - Shift or mask dates
#
# Even de-identified data can sometimes be re-identified. That’s why strict governance is required.
